# %%
import numpy as np

sample_rate = 32e3
time_step = 1 / sample_rate

signal = np.fromfile('../data/output.bin', dtype=np.float32)
time = np.arange(0, len(x)) * time_step

# %%
from matplotlib import pyplot as plt

plt.figure(dpi=300)
plt.axvline(0.95, color='orange')
plt.axvline(1.20, color='orange')
plt.scatter(time, signal, s=0.4)
plt.show()

# %%
from dsp import select_time_window

t, x = select_time_window(time, signal, 0.98, 1.20)

plt.figure(dpi=300)

plt.scatter(t, x, s=0.4)
plt.show()

# %%
from dsp import select_time_window

t, x = select_time_window(time, signal, 0.990, 1.005)

plt.figure(dpi=300)
plt.scatter(t, x, s=0.4)
plt.show()

# %%
from dsp import select_time_window

t, x = select_time_window(time, signal, 0.9915, 0.992)

plt.figure(dpi=300)
plt.scatter(t, x, s=0.4)
plt.show()

# %%
x.sum()
# Out:
# 12.0

# %%
from dsp import select_time_window

t, x = select_time_window(time, signal, 0.9955, 0.997)

plt.figure(dpi=300)
plt.scatter(t, x, s=0.4)
plt.show()

# %%
x.sum()
# Out:
# 35.0
